# %% [markdown]
# Запустите, пожалуйста, раздел "Подготовка" и приступайте к выполнению заданий.

# %% [markdown]
# ## Подготовка

# %% [markdown]
# ### Импорт библиотек

# %%
# Массивы
import numpy as np

# Отрисовка графиков
import matplotlib.pyplot as plt

# Загрузка из google облака
import gdown

# Преобразование категориальных данных в one hot encoding
from tensorflow.keras.utils import to_categorical

# Работа с папками и файлами
import os

# Утилиты работы со временем
import time

# Работа со случайными числами
import random

# Математические функции
import math

# Сохранение и загрузка структур данных Python
import pickle

# Параметризация аудио
import librosa

# Оптимизаторы для обучения моделей
from tensorflow.keras.optimizers import Adam, RMSprop

# Конструирование и загрузка моделей нейронных сетей
from tensorflow.keras.models import Sequential, Model, load_model

# Основные слои
from tensorflow.keras.layers import concatenate, Input, Dense, Dropout, BatchNormalization, Flatten, Conv1D, Conv2D, LSTM

# Разбиение на обучающую и проверочную выборку
from sklearn.model_selection import train_test_split

# Кодирование категориальных меток, нормирование числовых данных
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Матрица ошибок классификатора
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Отключение предупреждений
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ### Загрузка датасета и подготовка данных

# %%
# Загрузка датасета из облака
gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l12/genres.zip', None, quiet=False)

# Загрузка подготовленных данных
gdown.download('https://storage.yandexcloud.net/aiueducation/Content/base/l12/audio_data_mean.pickle', None, quiet=True)
# Out:
# Downloading...
# From: https://storage.yandexcloud.net/aiueducation/Content/base/l12/genres.zip
# To: /content/genres.zip
# 100%|██████████| 1.23G/1.23G [00:51<00:00, 23.7MB/s]
# 'audio_data_mean.pickle'

# %%
# Распаковка архива на локальный диск colab
# !unzip -qo genres.zip

# Проверка выгруженных папок
# !ls genres

# Проверка содержимого одной папки
# !ls genres/blues
# Out:
# blues  classical  country  disco  hiphop  jazz	metal  pop  reggae  rock
# blues.00000.au	blues.00020.au	blues.00040.au	blues.00060.au	blues.00080.au
# blues.00001.au	blues.00021.au	blues.00041.au	blues.00061.au	blues.00081.au
# blues.00002.au	blues.00022.au	blues.00042.au	blues.00062.au	blues.00082.au
# blues.00003.au	blues.00023.au	blues.00043.au	blues.00063.au	blues.00083.au
# blues.00004.au	blues.00024.au	blues.00044.au	blues.00064.au	blues.00084.au
# blues.00005.au	blues.00025.au	blues.00045.au	blues.00065.au	blues.00085.au
# blues.00006.au	blues.00026.au	blues.00046.au	blues.00066.au	blues.00086.au
# blues.00007.au	blues.00027.au	blues.00047.au	blues.00067.au	blues.00087.au
# blues.00008.au	blues.00028.au	blues.00048.au	blues.00068.au	blues.00088.au
# blues.00009.au	blues.00029.au	blues.00049.au	blues.00069.au	blues.00089.au
# blues.00010.au	blues.00030.au	blues.00050.au	blues.00070.au	blues.00090.au
# blues.00011.au	blues.00031.au	blues.00051.au	blues.00071.au	blues.00091.au
# blues.00012.au	blues.00032.au	blues.00052.au	blues.00072.au	blues.00092.au
# blues.00013.au	blues.00033.au	blues.00053.au	blues.00073.au	blues.00093.au
# blues.00014.au	blues.00034.au	blues.00054.au	blues.00074.au	blues.00094.au
# blues.00015.au	blues.00035.au	blues.00055.au	blues.00075.au	blues.00095.au
# blues.00016.au	blues.00036.au	blues.00056.au	blues.00076.au	blues.00096.au
# blues.00017.au	blues.00037.au	blues.00057.au	blues.00077.au	blues.00097.au
# blues.00018.au	blues.00038.au	blues.00058.au	blues.00078.au	blues.00098.au
# blues.00019.au	blues.00039.au	blues.00059.au	blues.00079.au	blues.00099.au

# %%
# Установка констант

FILE_DIR = './genres'                     # Папка с файлами датасета
CLASS_LIST = os.listdir(FILE_DIR)         # Список классов, порядок меток не определен!
CLASS_LIST.sort()                         # Сортировка списка классов для фиксации порядка меток
CLASS_COUNT = len(CLASS_LIST)             # Количество классов
CLASS_FILES = 100                         # Общее количество файлов в каждом классе
FILE_INDEX_TRAIN_SPLIT = 90               # Количество файлов каждого класса на основной набор
VALIDATION_SPLIT = 0.1                    # Доля проверочной выборки в основном наборе
DURATION_SEC = 30                         # Анализируемая длительность аудиосигнала
N_FFT = 8192                              # Размер окна преобразования Фурье для расчета спектра
HOP_LENGTH = 512                          # Объем данных для расчета одного набора признаков

# %%
# Проверка списка классов
print(CLASS_LIST)
# Out:
# ['blues', 'classical', 'country', 'disco', 'hiphop', 'jazz', 'metal', 'pop', 'reggae', 'rock']

# %%
# Функция параметризации аудио

def get_features(y,                     # волновое представление сигнала
                 sr,                    # частота дискретизации сигнала y
                 n_fft=N_FFT,           # размер скользящего окна БПФ
                 hop_length=HOP_LENGTH  # шаг скользящего окна БПФ
                 ):
    # Вычисление различных параметров (признаков) аудио

    # Хромаграмма
    chroma_stft = librosa.feature.chroma_stft(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
    # Мел-кепстральные коэффициенты
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
    # Среднеквадратическая амплитуда
    rmse = librosa.feature.rms(y=y, hop_length=hop_length)
    # Спектральный центроид
    spec_cent = librosa.feature.spectral_centroid(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
    # Ширина полосы частот
    spec_bw = librosa.feature.spectral_bandwidth(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
    # Спектральный спад частоты
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length)
    # Пересечения нуля
    zcr = librosa.feature.zero_crossing_rate(y, hop_length=hop_length)

    # Сборка параметров в общий список:
    # На один файл один усредненный вектор признаков
    features = {'rmse': rmse.mean(axis=1, keepdims=True),
                'spct': spec_cent.mean(axis=1, keepdims=True),
                'spbw': spec_bw.mean(axis=1, keepdims=True),
                'roff': rolloff.mean(axis=1, keepdims=True),
                'zcr' : zcr.mean(axis=1, keepdims=True),
                'mfcc': mfcc.mean(axis=1, keepdims=True),
                'stft': chroma_stft.mean(axis=1, keepdims=True)}

    return features

# %%
# Функция объединения признаков в набор векторов

def stack_features(feat  # словарь признаков, отдельные векторы по ключу каждого признака
                   ):
    features = None
    for v in feat.values():
        features = np.vstack((features, v)) if features is not None else v

    return features.T

# %%
# Функция формирования набора признаков и метки класса для аудиофайла

def get_feature_list_from_file(class_index,  # индекс класса файла song_name
                               song_name,    # имя аудиофайла
                               duration_sec  # длительность аудио в секундах
                               ):
    # Загрузка в y первых duration_sec секунд аудиосигнала
    y, sr = librosa.load(song_name, mono=True, duration=duration_sec)

    # Извлечение параметров из аудиосигнала
    features = get_features(y, sr)
    feature_set = stack_features(features)

    # Перевод номера класса в one hot encoding
    y_label = to_categorical(class_index, CLASS_COUNT)

    return feature_set, y_label

# %%
# Функция формирования подвыборки признаков и меток класса для одного файла

def process_file(class_index,  # индекс класса аудиофайла
                 file_index,   # индекс (порядковый номер) аудиофайла в папке класса
                 duration_sec  # длительность аудио в секундах
                 ):
    x_list = []
    y_list = []
    class_name = CLASS_LIST[class_index]

    # Извлечение имени произведения
    song_name = f'{FILE_DIR}/{class_name}/{class_name}.{str(file_index).zfill(5)}.au'

    # Выборка признаков и метки класса для произведения
    feature_set, y_label = get_feature_list_from_file(class_index,
                                                        song_name,
                                                        duration_sec)

    # Добавление данных в наборы
    for j in range(feature_set.shape[0]):
        x_list.append(feature_set[j])
        y_list.append(y_label)

    # Возврат имени файла и numpy-массивов призанков и меток класса
    return song_name, \
           np.array(x_list).astype('float32'), \
           np.array(y_list).astype('float32')

# %%
# Функция формирования набора данных из файлов всех классов по диапазону номеров файлов

def extract_data(file_index_start,          # начальный индекс аудиофайла
                 file_index_end,            # конечный индекс аудиофайла (не достигая)
                 duration_sec=DURATION_SEC  # длительность аудио в секундах
                 ):

    # Списки для последовательностей входных данных и меток класса
    x_data = None
    y_data = None

    # Фиксация времени старта формирования выборки
    curr_time = time.time()

    # Для всех классов:
    for class_index in range(len(CLASS_LIST)):
        # Для всех файлов текущего класса из заданного диапазона номеров:
        for file_index in range(file_index_start, file_index_end):
            # Обработка одного файла и добавление данных к общим массивам
            _, file_x_data, file_y_data = process_file(class_index, file_index, duration_sec)
            x_data = file_x_data if x_data is None else np.vstack([x_data, file_x_data])
            y_data = file_y_data if y_data is None else np.vstack([y_data, file_y_data])

        # Вывод информации о готовности обработки датасета
        print(f'Жанр {CLASS_LIST[class_index]} готов -> {round(time.time() - curr_time)} c')
        curr_time = time.time()

    # Возврат массивов набора данных
    return x_data, y_data

# %%
# Извлекаем признаки из аудиофайлов ТЕМ ЖЕ способом, что используется в classify_test_files.
# Это критически важно, чтобы обучение и тест согласовывались.
# Pickle-файл НЕ используем — там признаки могут отличаться по порядку/способу извлечения.

x_train_data, y_train_data = extract_data(file_index_start=0,
                                          file_index_end=FILE_INDEX_TRAIN_SPLIT,
                                          duration_sec=DURATION_SEC)

print('Форма x_train_data:', x_train_data.shape)
print('Форма y_train_data:', y_train_data.shape)
# Out:
# Жанр blues готов -> 126 c
# Жанр classical готов -> 111 c
# Жанр country готов -> 111 c
# Жанр disco готов -> 111 c
# Жанр hiphop готов -> 111 c
# Жанр jazz готов -> 112 c
# Жанр metal готов -> 112 c
# Жанр pop готов -> 111 c
# Жанр reggae готов -> 111 c
# Жанр rock готов -> 110 c
# Форма x_train_data: (900, 37)
# Форма y_train_data: (900, 10)

# %%
# Нормирование признаков в соответствии со стандартным нормальным распределением

x_scaler = StandardScaler()
x_train_data_scaled = x_scaler.fit_transform(x_train_data)

# %%
# Разделение набора данных на обучающую и проверочную выборки
# Параметр stratify указывает метки классов, по которым происходит балансировка разделения

x_train, x_val, y_train, y_val = train_test_split(x_train_data_scaled,
                                                  y_train_data,
                                                  stratify=y_train_data,
                                                  test_size=VALIDATION_SPLIT)

# %% [markdown]
# ### Функция вывода графиков точности и ошибки по эпохам обучения

# %%
# Вывод графиков точности и ошибки распознавания на обучающей и проверочной выборках

def show_history(history  # объект-результат метода обучения .fit()
                 ):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5))
    fig.suptitle('График процесса обучения модели')
    ax1.plot(history.history['accuracy'],
               label='Доля верных ответов на обучающем наборе')
    ax1.plot(history.history['val_accuracy'],
               label='Доля верных ответов на проверочном наборе')
    ax1.xaxis.get_major_locator().set_params(integer=True)
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('Доля верных ответов')
    ax1.legend()

    ax2.plot(history.history['loss'],
               label='Ошибка на обучающем наборе')
    ax2.plot(history.history['val_loss'],
               label='Ошибка на проверочном наборе')
    ax2.xaxis.get_major_locator().set_params(integer=True)
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

# %% [markdown]
# ### Функции визуализации распознавания отдельных звуковых файлов

# %%
# Классификация файла и визуализация предсказания модели для него

def classify_file(model,        # обученная модель классификатора
                  x_scaler,     # настроенный нормировщих входных данных
                  class_index,  # верный индекс класса аудиофайла
                  file_index    # индекс (порядковый номер) аудиофайла в папке
                  ):
    # Подготовка выборки данных файла произведения
    song_name, file_x_data, file_y_data = process_file(class_index, file_index, DURATION_SEC)

    # Нормирование признаков уже настроенным нормировщиком
    file_x_data = x_scaler.transform(file_x_data)

    print('Файл:', song_name)
    print('Векторы для предсказания:', file_x_data.shape)

    # Вычисление предсказания по выборке
    predict = model.predict(file_x_data)
    # Определение среднего предсказания (голосование)
    predict_mean = predict.mean(axis=0)
    # Определение индекса класса по результату голосования
    predict_class_index = np.argmax(predict_mean)
    # Вычисление признака правильного предсказания
    predict_good = predict_class_index == class_index

    # Визуализация предсказания сети для файла
    plt.figure(figsize=(10,3))
    print('Классификация сети:', CLASS_LIST[predict_class_index], '-', 'ВЕРНО :-)' if predict_good else 'НЕВЕРНО.')
    plt.title('Среднее распределение векторов предсказаний')
    plt.bar(CLASS_LIST, predict_mean, color='g' if predict_good else 'r')
    plt.show()
    print('---------------------------------------------------------------')

    # Возврат результата предсказания
    return predict_class_index

# %%
# Классификация и визуализация нескольких файлов каждого класса

def classify_test_files(model,       # обученная модель классификатора
                        x_scaler,    # настроенный нормировщих входных данных
                        from_index,  # индекс аудиофайла, с которого начинать визуализацию
                        n_files):    # количество файлов для визуализации
    predict_all = 0
    predict_good = 0
    y_true = []
    y_pred = []

    # Классификация каждого файла и аккумуляция результатов классификации
    for class_index in range(CLASS_COUNT):
        for file_index in range(from_index, from_index + n_files):
            predict_class_index = classify_file(model, x_scaler, class_index, file_index)
            y_true.append(class_index)
            y_pred.append(predict_class_index)
            predict_all += 1
            predict_good += (predict_class_index == class_index)

    # Расчет и вывод итогов классификации
    good_ratio = round(predict_good / predict_all * 100., 2)
    print(f'=== Обработано образцов: {predict_all}, из них распознано верно: {predict_good}, доля верных: {good_ratio}% ===')

    # Построение матрицы ошибок без нормализации, покажет попадания в штуках
    cm = confusion_matrix(y_true, y_pred)

    # Отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_title('Матрица ошибок по файлам аудио (не нормализованная)')
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=CLASS_LIST)
    disp.plot(ax=ax)
    plt.show()

# %% [markdown]
# ##Заданиe

# %% [markdown]
# В предыдущих ячейках были подготовлены все данные для обучения модели нейронной сети.
# 1. Проверьте форму данных обучающей и проверочной выборок (выведите на экран).

# %%
# Ваше решение
print('Форма обучающей выборки:')
print('  x_train:', x_train.shape)
print('  y_train:', y_train.shape)

print('Форма проверочной выборки:')
print('  x_val:  ', x_val.shape)
print('  y_val:  ', y_val.shape)
# Out:
# Форма обучающей выборки:
#   x_train: (810, 37)
#   y_train: (810, 10)
# Форма проверочной выборки:
#   x_val:   (90, 37)
#   y_val:   (90, 10)

# %% [markdown]
# 2. Составьте модель классификатора на полносвязных слоях и сохраните ее в переменной **model**. Для этого:
#  - Используйте заготовку для последовательной модели **Sequential**;
#  - Добавьте полносвязный слой на **64** нейрона с активационной функцией **'relu'**, после него добавьте слой **Dropout** с долей отключаемых нейронов **30%**;
#  - Добавьте следующий полносвязный слой на **32** нейрона с активационной функцией **'relu'**, после него добавьте слой **Dropout** с долей отключаемых нейронов **30%**;
#  - Добавьте следующий полносвязный слой на **16** нейронов с активационной функцией **'relu'**, после него добавьте слой **Dropout** с долей отключаемых нейронов **20%**;
#  - Добавьте слой пакетной нормализации;
#  - Добавьте финальный полносвязный слой классификатора на число нейронов по числу классов (**CLASS_COUNT**) с активационной функцией **'softmax'** .

# %%
# Ваше решение
model = Sequential()

# Полносвязный слой на 64 нейрона + Dropout 30%
model.add(Dense(64, activation='relu', input_shape=(x_train.shape[1],)))
model.add(Dropout(0.3))

# Полносвязный слой на 32 нейрона + Dropout 30%
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.3))

# Полносвязный слой на 16 нейронов + Dropout 20%
model.add(Dense(16, activation='relu'))
model.add(Dropout(0.2))

# Слой пакетной нормализации
model.add(BatchNormalization())

# Финальный слой классификатора с softmax
model.add(Dense(CLASS_COUNT, activation='softmax'))

# %% [markdown]
# 3. Откомпилируйте созданную модель методом `.compile()` с указанием оптимизатора **Adam** и начальным шагом обучения **0.0001**, функцией ошибки **'categorical_crossentropy'** и метрикой **'accuracy'**;
# Выведите на экран сводку архитектуры полученной модели методом `.summary()` .

# %%
# Ваше решение
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         2,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 16)             │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │           170 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,274 (20.60 KB)
#  Trainable params: 5,242 (20.48 KB)
#  Non-trainable params: 32 (128.00 B)

# %% [markdown]
# 4. Обучите модель и выведите графики обучения:
#  - Обучите созданную и откомпилированную модель классификатора на данных обучающей выборки **x_train, y_train**, используя проверочные данные **x_val, y_val**, размер батча **32** и количество эпох **1000**. Результаты обучения сохраните в переменной **history** .
#  - В разделе **"Функция вывода графиков точности и ошибки по эпохам обучения"** найдите определение функции `show_history()`, изучите требуемые параметры для нее и используйте для построения графиков точности и ошибки на протяжении эпох обучения.

# %%
# Ваше решение
history = model.fit(x_train, y_train,
                    batch_size=32,
                    epochs=1000,
                    validation_data=(x_val, y_val),
                    verbose=1)

show_history(history)
# Out:
# Epoch 1/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 8s 158ms/step - accuracy: 0.0938 - loss: 2.8145 - val_accuracy: 0.0778 - val_loss: 2.3766
# Epoch 2/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1185 - loss: 2.7254 - val_accuracy: 0.1000 - val_loss: 2.3355
# Epoch 3/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0926 - loss: 2.7153 - val_accuracy: 0.1222 - val_loss: 2.3079
# Epoch 4/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.1247 - loss: 2.6658 - val_accuracy: 0.1556 - val_loss: 2.2852
# Epoch 5/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1235 - loss: 2.6481 - val_accuracy: 0.1778 - val_loss: 2.2673
# Epoch 6/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1148 - loss: 2.6464 - val_accuracy: 0.1778 - val_loss: 2.2464
# Epoch 7/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1321 - loss: 2.5385 - val_accuracy: 0.1444 - val_loss: 2.2284
# Epoch 8/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1395 - loss: 2.5716 - val_accuracy: 0.1556 - val_loss: 2.2074
# Epoch 9/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1420 - loss: 2.5327 - val_accuracy: 0.1667 - val_loss: 2.1872
# Epoch 10/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1333 - loss: 2.5001 - val_accuracy: 0.1667 - val_loss: 2.1670
# Epoch 11/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1321 - loss: 2.4730 - val_accuracy: 0.1667 - val_loss: 2.1505
# Epoch 12/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1543 - loss: 2.4220 - val_accuracy: 0.1889 - val_loss: 2.1343
# Epoch 13/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1691 - loss: 2.4210 - val_accuracy: 0.1778 - val_loss: 2.1184
# Epoch 14/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1580 - loss: 2.4014 - val_accuracy: 0.1889 - val_loss: 2.1047
# Epoch 15/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1593 - loss: 2.4264 - val_accuracy: 0.2000 - val_loss: 2.0923
# Epoch 16/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1506 - loss: 2.3791 - val_accuracy: 0.2000 - val_loss: 2.0799
# Epoch 17/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1580 - loss: 2.3742 - val_accuracy: 0.2222 - val_loss: 2.0659
# Epoch 18/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1753 - loss: 2.3577 - val_accuracy: 0.1889 - val_loss: 2.0551
# Epoch 19/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1728 - loss: 2.3423 - val_accuracy: 0.1889 - val_loss: 2.0463
# Epoch 20/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1704 - loss: 2.3334 - val_accuracy: 0.2000 - val_loss: 2.0354
# Epoch 21/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1901 - loss: 2.3272 - val_accuracy: 0.1889 - val_loss: 2.0253
# Epoch 22/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1889 - loss: 2.2924 - val_accuracy: 0.1889 - val_loss: 2.0170
# Epoch 23/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2000 - loss: 2.3376 - val_accuracy: 0.2000 - val_loss: 2.0076
# Epoch 24/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1951 - loss: 2.3279 - val_accuracy: 0.2000 - val_loss: 1.9999
# Epoch 25/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1852 - loss: 2.2803 - val_accuracy: 0.2111 - val_loss: 1.9928
# Epoch 26/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2037 - loss: 2.2812 - val_accuracy: 0.2333 - val_loss: 1.9892
# Epoch 27/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.1988 - loss: 2.3018 - val_accuracy: 0.2444 - val_loss: 1.9825
# Epoch 28/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2000 - loss: 2.2679 - val_accuracy: 0.2444 - val_loss: 1.9758
# Epoch 29/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2235 - loss: 2.2184 - val_accuracy: 0.2444 - val_loss: 1.9687
# Epoch 30/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1889 - loss: 2.2900 - val_accuracy: 0.2444 - val_loss: 1.9599
# Epoch 31/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2062 - loss: 2.2350 - val_accuracy: 0.2778 - val_loss: 1.9542
# Epoch 32/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1926 - loss: 2.2602 - val_accuracy: 0.2667 - val_loss: 1.9500
# Epoch 33/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2123 - loss: 2.2237 - val_accuracy: 0.2556 - val_loss: 1.9477
# Epoch 34/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2111 - loss: 2.2041 - val_accuracy: 0.2778 - val_loss: 1.9446
# Epoch 35/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2210 - loss: 2.1689 - val_accuracy: 0.2778 - val_loss: 1.9421
# Epoch 36/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2407 - loss: 2.1634 - val_accuracy: 0.3222 - val_loss: 1.9342
# Epoch 37/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2198 - loss: 2.1567 - val_accuracy: 0.3000 - val_loss: 1.9308
# Epoch 38/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2333 - loss: 2.1218 - val_accuracy: 0.3111 - val_loss: 1.9247
# Epoch 39/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2235 - loss: 2.1394 - val_accuracy: 0.3333 - val_loss: 1.9184
# Epoch 40/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2037 - loss: 2.1889 - val_accuracy: 0.3444 - val_loss: 1.9151
# Epoch 41/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2272 - loss: 2.1540 - val_accuracy: 0.3222 - val_loss: 1.9111
# Epoch 42/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2346 - loss: 2.1160 - val_accuracy: 0.3222 - val_loss: 1.9074
# Epoch 43/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2506 - loss: 2.1379 - val_accuracy: 0.3333 - val_loss: 1.9033
# Epoch 44/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2358 - loss: 2.1278 - val_accuracy: 0.3333 - val_loss: 1.8993
# Epoch 45/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2568 - loss: 2.0981 - val_accuracy: 0.3333 - val_loss: 1.8943
# Epoch 46/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2407 - loss: 2.1384 - val_accuracy: 0.3556 - val_loss: 1.8900
# Epoch 47/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2395 - loss: 2.1147 - val_accuracy: 0.3444 - val_loss: 1.8881
# Epoch 48/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2358 - loss: 2.1066 - val_accuracy: 0.3556 - val_loss: 1.8857
# Epoch 49/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2543 - loss: 2.1150 - val_accuracy: 0.3556 - val_loss: 1.8851
# Epoch 50/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2457 - loss: 2.0932 - val_accuracy: 0.3556 - val_loss: 1.8821
# Epoch 51/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2469 - loss: 2.1127 - val_accuracy: 0.3556 - val_loss: 1.8804
# Epoch 52/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2407 - loss: 2.0948 - val_accuracy: 0.3333 - val_loss: 1.8780
# Epoch 53/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.
1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4741 - loss: 1.5981 - val_accuracy: 0.5000 - val_loss: 1.4994
# Epoch 212/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4358 - loss: 1.6077 - val_accuracy: 0.5000 - val_loss: 1.4945
# Epoch 213/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4259 - loss: 1.6030 - val_accuracy: 0.5000 - val_loss: 1.4917
# Epoch 214/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4321 - loss: 1.6136 - val_accuracy: 0.5000 - val_loss: 1.4884
# Epoch 215/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4383 - loss: 1.5695 - val_accuracy: 0.5000 - val_loss: 1.4854
# Epoch 216/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4481 - loss: 1.6013 - val_accuracy: 0.4889 - val_loss: 1.4854
# Epoch 217/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4160 - loss: 1.5993 - val_accuracy: 0.5000 - val_loss: 1.4853
# Epoch 218/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4074 - loss: 1.6150 - val_accuracy: 0.5111 - val_loss: 1.4842
# Epoch 219/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4086 - loss: 1.6273 - val_accuracy: 0.5000 - val_loss: 1.4794
# Epoch 220/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4358 - loss: 1.5751 - val_accuracy: 0.5111 - val_loss: 1.4809
# Epoch 221/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4247 - loss: 1.5882 - val_accuracy: 0.5000 - val_loss: 1.4793
# Epoch 222/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4444 - loss: 1.5682 - val_accuracy: 0.5111 - val_loss: 1.4785
# Epoch 223/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4444 - loss: 1.6165 - val_accuracy: 0.5000 - val_loss: 1.4758
# Epoch 224/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4235 - loss: 1.6652 - val_accuracy: 0.5000 - val_loss: 1.4761
# Epoch 225/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4272 - loss: 1.6198 - val_accuracy: 0.4889 - val_loss: 1.4750
# Epoch 226/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4494 - loss: 1.5599 - val_accuracy: 0.5000 - val_loss: 1.4738
# Epoch 227/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4358 - loss: 1.5835 - val_accuracy: 0.5000 - val_loss: 1.4700
# Epoch 228/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4370 - loss: 1.5674 - val_accuracy: 0.5111 - val_loss: 1.4707
# Epoch 229/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4321 - loss: 1.5874 - val_accuracy: 0.5000 - val_loss: 1.4725
# Epoch 230/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4679 - loss: 1.5064 - val_accuracy: 0.4889 - val_loss: 1.4714
# Epoch 231/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4420 - loss: 1.5841 - val_accuracy: 0.5000 - val_loss: 1.4664
# Epoch 232/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4358 - loss: 1.5818 - val_accuracy: 0.5000 - val_loss: 1.4638
# Epoch 233/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4469 - loss: 1.5653 - val_accuracy: 0.5111 - val_loss: 1.4623
# Epoch 234/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4654 - loss: 1.5553 - val_accuracy: 0.5111 - val_loss: 1.4608
# Epoch 235/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4259 - loss: 1.5772 - val_accuracy: 0.5000 - val_loss: 1.4587
# Epoch 236/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4519 - loss: 1.5863 - val_accuracy: 0.5000 - val_loss: 1.4568
# Epoch 237/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4457 - loss: 1.5913 - val_accuracy: 0.5000 - val_loss: 1.4576
# Epoch 238/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4370 - loss: 1.5680 - val_accuracy: 0.5111 - val_loss: 1.4553
# Epoch 239/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4580 - loss: 1.5573 - val_accuracy: 0.5111 - val_loss: 1.4534
# Epoch 240/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4642 - loss: 1.5849 - val_accuracy: 0.5000 - val_loss: 1.4538
# Epoch 241/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4691 - loss: 1.5510 - val_accuracy: 0.5000 - val_loss: 1.4524
# Epoch 242/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4420 - loss: 1.5364 - val_accuracy: 0.5111 - val_loss: 1.4497
# Epoch 243/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4519 - loss: 1.5450 - val_accuracy: 0.5000 - val_loss: 1.4444
# Epoch 244/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.
1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6728 - loss: 1.0017 - val_accuracy: 0.6111 - val_loss: 1.0772
# Epoch 880/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6728 - loss: 0.9807 - val_accuracy: 0.6333 - val_loss: 1.0789
# Epoch 881/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6926 - loss: 0.9546 - val_accuracy: 0.6333 - val_loss: 1.0820
# Epoch 882/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6691 - loss: 0.9960 - val_accuracy: 0.6333 - val_loss: 1.0818
# Epoch 883/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6679 - loss: 0.9472 - val_accuracy: 0.6222 - val_loss: 1.0781
# Epoch 884/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6877 - loss: 0.9401 - val_accuracy: 0.6222 - val_loss: 1.0779
# Epoch 885/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6926 - loss: 0.9482 - val_accuracy: 0.6111 - val_loss: 1.0771
# Epoch 886/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6556 - loss: 1.0174 - val_accuracy: 0.6111 - val_loss: 1.0761
# Epoch 887/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6617 - loss: 0.9728 - val_accuracy: 0.6222 - val_loss: 1.0736
# Epoch 888/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6728 - loss: 0.9492 - val_accuracy: 0.6111 - val_loss: 1.0712
# Epoch 889/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6741 - loss: 0.9624 - val_accuracy: 0.6111 - val_loss: 1.0705
# Epoch 890/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6531 - loss: 0.9926 - val_accuracy: 0.6111 - val_loss: 1.0699
# Epoch 891/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6877 - loss: 0.9556 - val_accuracy: 0.6000 - val_loss: 1.0708
# Epoch 892/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6827 - loss: 0.9692 - val_accuracy: 0.6000 - val_loss: 1.0722
# Epoch 893/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6938 - loss: 0.9029 - val_accuracy: 0.6000 - val_loss: 1.0709
# Epoch 894/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6741 - loss: 0.9533 - val_accuracy: 0.6000 - val_loss: 1.0690
# Epoch 895/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6617 - loss: 1.0048 - val_accuracy: 0.6111 - val_loss: 1.0684
# Epoch 896/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6654 - loss: 1.0070 - val_accuracy: 0.6222 - val_loss: 1.0648
# Epoch 897/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6654 - loss: 0.9323 - val_accuracy: 0.6222 - val_loss: 1.0616
# Epoch 898/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6630 - loss: 1.0165 - val_accuracy: 0.6222 - val_loss: 1.0659
# Epoch 899/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6778 - loss: 0.9530 - val_accuracy: 0.6111 - val_loss: 1.0677
# Epoch 900/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6543 - loss: 1.0141 - val_accuracy: 0.6222 - val_loss: 1.0652
# Epoch 901/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6815 - loss: 0.9478 - val_accuracy: 0.6333 - val_loss: 1.0653
# Epoch 902/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6802 - loss: 0.9707 - val_accuracy: 0.6333 - val_loss: 1.0628
# Epoch 903/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6753 - loss: 0.9354 - val_accuracy: 0.6333 - val_loss: 1.0651
# Epoch 904/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6988 - loss: 0.9211 - val_accuracy: 0.6222 - val_loss: 1.0659
# Epoch 905/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6790 - loss: 0.9530 - val_accuracy: 0.6222 - val_loss: 1.0659
# Epoch 906/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6852 - loss: 0.9407 - val_accuracy: 0.6222 - val_loss: 1.0639
# Epoch 907/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6444 - loss: 0.9412 - val_accuracy: 0.6444 - val_loss: 1.0607
# Epoch 908/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6778 - loss: 0.9613 - val_accuracy: 0.6333 - val_loss: 1.0598
# Epoch 909/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6914 - loss: 0.9377 - val_accuracy: 0.6333 - val_loss: 1.0587
# Epoch 910/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6765 - loss: 0.9561 - val_accuracy: 0.6444 - val_loss: 1.0618
# Epoch 911/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6593 - loss: 0.9890 - val_accuracy: 0.6333 - val_loss: 1.0681
# Epoch 912/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6679 - loss: 0.9639 - val_accuracy: 0.6222 - val_loss: 1.0726
# Epoch 913/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6728 - loss: 0.9522 - val_accuracy: 0.6222 - val_loss: 1.0736
# Epoch 914/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6679 - loss: 1.0009 - val_accuracy: 0.6222 - val_loss: 1.0729
# Epoch 915/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6691 - loss: 0.9791 - val_accuracy: 0.6333 - val_loss: 1.0684
# Epoch 916/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6753 - loss: 0.9310 - val_accuracy: 0.6333 - val_loss: 1.0692
# Epoch 917/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6815 - loss: 0.9386 - val_accuracy: 0.6444 - val_loss: 1.0694
# Epoch 918/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6852 - loss: 0.9485 - val_accuracy: 0.6444 - val_loss: 1.0702
# Epoch 919/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6765 - loss: 0.9775 - val_accuracy: 0.6333 - val_loss: 1.0703
# Epoch 920/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6704 - loss: 0.9795 - val_accuracy: 0.6333 - val_loss: 1.0683
# Epoch 921/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6778 - loss: 0.9532 - val_accuracy: 0.6444 - val_loss: 1.0648
# Epoch 922/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6679 - loss: 0.9959 - val_accuracy: 0.6333 - val_loss: 1.0632
# Epoch 923/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6617 - loss: 0.9961 - val_accuracy: 0.6444 - val_loss: 1.0601
# Epoch 924/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6889 - loss: 0.8949 - val_accuracy: 0.6444 - val_loss: 1.0608
# Epoch 925/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6778 - loss: 0.9353 - val_accuracy: 0.6444 - val_loss: 1.0607
# Epoch 926/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6716 - loss: 0.9705 - val_accuracy: 0.6333 - val_loss: 1.0579
# Epoch 927/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6963 - loss: 0.8902 - val_accuracy: 0.6333 - val_loss: 1.0554
# Epoch 928/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6593 - loss: 0.9991 - val_accuracy: 0.6222 - val_loss: 1.0552
# Epoch 929/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6778 - loss: 0.9485 - val_accuracy: 0.6333 - val_loss: 1.0597
# Epoch 930/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6778 - loss: 0.9841 - val_accuracy: 0.6333 - val_loss: 1.0633
# Epoch 931/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6704 - loss: 0.9602 - val_accuracy: 0.6333 - val_loss: 1.0632
# Epoch 932/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6889 - loss: 0.9335 - val_accuracy: 0.6333 - val_loss: 1.0625
# Epoch 933/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6877 - loss: 0.9525 - val_accuracy: 0.6333 - val_loss: 1.0601
# Epoch 934/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6815 - loss: 0.8964 - val_accuracy: 0.6333 - val_loss: 1.0622
# Epoch 935/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6519 - loss: 0.9744 - val_accuracy: 0.6333 - val_loss: 1.0644
# Epoch 936/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6531 - loss: 0.9688 - val_accuracy: 0.6333 - val_loss: 1.0665
# Epoch 937/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6617 - loss: 0.9704 - val_accuracy: 0.6333 - val_loss: 1.0673
# Epoch 938/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6988 - loss: 0.9428 - val_accuracy: 0.6111 - val_loss: 1.0673
# Epoch 939/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6877 - loss: 0.9010 - val_accuracy: 0.6111 - val_loss: 1.0693
# Epoch 940/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6802 - loss: 0.9848 - val_accuracy: 0.6111 - val_loss: 1.0670
# Epoch 941/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7111 - loss: 0.9133 - val_accuracy: 0.6111 - val_loss: 1.0676
# Epoch 942/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6951 - loss: 0.9234 - val_accuracy: 0.6111 - val_loss: 1.0668
# Epoch 943/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6827 - loss: 0.9277 - val_accuracy: 0.6222 - val_loss: 1.0647
# Epoch 944/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6914 - loss: 0.8915 - val_accuracy: 0.6222 - val_loss: 1.0652
# Epoch 945/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6889 - loss: 0.9050 - val_accuracy: 0.6222 - val_loss: 1.0644
# Epoch 946/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.
1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6938 - loss: 0.9471 - val_accuracy: 0.6222 - val_loss: 1.0561
# Epoch 979/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6877 - loss: 0.9625 - val_accuracy: 0.6222 - val_loss: 1.0570
# Epoch 980/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7074 - loss: 0.9090 - val_accuracy: 0.6222 - val_loss: 1.0550
# Epoch 981/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7049 - loss: 0.9457 - val_accuracy: 0.6222 - val_loss: 1.0572
# Epoch 982/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6951 - loss: 0.8997 - val_accuracy: 0.6111 - val_loss: 1.0599
# Epoch 983/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6815 - loss: 0.9348 - val_accuracy: 0.6222 - val_loss: 1.0635
# Epoch 984/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6975 - loss: 0.9365 - val_accuracy: 0.6222 - val_loss: 1.0600
# Epoch 985/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7086 - loss: 0.8989 - val_accuracy: 0.6111 - val_loss: 1.0604
# Epoch 986/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6704 - loss: 1.0230 - val_accuracy: 0.6222 - val_loss: 1.0587
# Epoch 987/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7148 - loss: 0.8482 - val_accuracy: 0.6222 - val_loss: 1.0589
# Epoch 988/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7160 - loss: 0.8839 - val_accuracy: 0.6222 - val_loss: 1.0544
# Epoch 989/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6988 - loss: 0.8856 - val_accuracy: 0.6333 - val_loss: 1.0515
# Epoch 990/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6938 - loss: 0.8866 - val_accuracy: 0.6222 - val_loss: 1.0569
# Epoch 991/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6914 - loss: 0.9018 - val_accuracy: 0.6222 - val_loss: 1.0576
# Epoch 992/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6864 - loss: 0.9676 - val_accuracy: 0.6333 - val_loss: 1.0577
# Epoch 993/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7173 - loss: 0.8708 - val_accuracy: 0.6333 - val_loss: 1.0580
# Epoch 994/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6852 - loss: 0.9031 - val_accuracy: 0.6333 - val_loss: 1.0588
# Epoch 995/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6877 - loss: 0.9100 - val_accuracy: 0.6333 - val_loss: 1.0579
# Epoch 996/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6827 - loss: 0.9350 - val_accuracy: 0.6333 - val_loss: 1.0572
# Epoch 997/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6741 - loss: 0.9188 - val_accuracy: 0.6222 - val_loss: 1.0563
# Epoch 998/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6852 - loss: 0.9074 - val_accuracy: 0.6222 - val_loss: 1.0545
# Epoch 999/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6901 - loss: 0.9081 - val_accuracy: 0.6222 - val_loss: 1.0570
# Epoch 1000/1000
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6864 - loss: 0.8633 - val_accuracy: 0.6222 - val_loss: 1.0575

# %% [markdown]
# 5. Проверьте работу модели:
#  - В разделе **Функции визуализации распознавания отдельных звуковых файлов** найдите определение функции `classify_test_files()` и изучите ее параметры. Используйте функцию для визуализации работы классификатора на произвольном количестве тестовых звуковых файлов, полагая, что:
#  - вы используете обученная в задании 4 модель классификатора аудио;
#  - нормализатор **x_scaler** уже настроен ранее в ноутбуке, и его нужно передать в функцию `classify_test_files()` вместо параметра **x_scaler**;
#  - тестовые звуковые файлы начинаются с индекса **90** и всего их ровно **10** для каждого класса.

# %%
# Ваше решение
classify_test_files(model=model,
                    x_scaler=x_scaler,
                    from_index=90,
                    n_files=10)
# Out:
# Файл: ./genres/blues/blues.00090.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 637ms/step
# Классификация сети: blues - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/blues/blues.00091.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Классификация сети: rock - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/blues/blues.00092.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Классификация сети: blues - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/blues/blues.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Классификация сети: blues - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/blues/blues.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Классификация сети: blues - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/blues/blues.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Классификация сети: blues - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/blues/blues.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Классификация сети: country - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/blues/blues.00097.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Классификация сети: blues - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/blues/blues.00098.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Классификация сети: rock - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/blues/blues.00099.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Классификация сети: country - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/classical/classical.00090.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Классификация сети: jazz - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/classical/classical.00091.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Классификация сети: jazz - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/classical/classical.00092.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Классификация сети: jazz - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/classical/classical.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Классификация сети: jazz - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/classical/classical.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Классификация сети: classical - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/classical/classical.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Классификация сети: classical - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/classical/classical.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Классификация сети: classical - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/classical/classical.00097.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Классификация сети: classical - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/classical/classical.00098.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: jazz - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/classical/classical.00099.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Классификация сети: jazz - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/country/country.00090.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Классификация сети: country - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/country/country.00091.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Классификация сети: jazz - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/country/country.00092.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Классификация сети: rock - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/country/country.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Классификация сети: country - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/country/country.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Классификация сети: blues - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/country/country.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# Классификация сети: blues - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/country/country.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Классификация сети: blues - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/country/country.00097.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Классификация сети: blues - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/country/country.00098.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Классификация сети: blues - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/country/country.00099.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: blues - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/disco/disco.00090.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Классификация сети: disco - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/disco/disco.00091.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Классификация сети: rock - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/disco/disco.00092.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Классификация сети: reggae - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/disco/disco.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Классификация сети: disco - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/disco/disco.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Классификация сети: rock - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/disco/disco.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: metal - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/disco/disco.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Классификация сети: rock - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/disco/disco.00097.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Классификация сети: hiphop - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/disco/disco.00098.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Классификация сети: disco - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/disco/disco.00099.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Классификация сети: disco - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/hiphop/hiphop.00090.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Классификация сети: hiphop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/hiphop/hiphop.00091.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Классификация сети: hiphop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/hiphop/hiphop.00092.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Классификация сети: hiphop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/hiphop/hiphop.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Классификация сети: metal - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/hiphop/hiphop.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Классификация сети: hiphop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/hiphop/hiphop.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Классификация сети: metal - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/hiphop/hiphop.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Классификация сети: hiphop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/hiphop/hiphop.00097.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Классификация сети: hiphop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/hiphop/hiphop.00098.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Классификация сети: hiphop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/hiphop/hiphop.00099.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Классификация сети: rock - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/jazz/jazz.00090.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: jazz - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/jazz/jazz.00091.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# Классификация сети: jazz - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/jazz/jazz.00092.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Классификация сети: jazz - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/jazz/jazz.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Классификация сети: jazz - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/jazz/jazz.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Классификация сети: jazz - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/jazz/jazz.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Классификация сети: jazz - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/jazz/jazz.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Классификация сети: jazz - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/jazz/jazz.00097.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Классификация сети: jazz - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/jazz/jazz.00098.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: jazz - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/jazz/jazz.00099.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Классификация сети: jazz - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/metal/metal.00090.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Классификация сети: country - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/metal/metal.00091.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Классификация сети: rock - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/metal/metal.00092.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Классификация сети: country - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/metal/metal.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: metal - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/metal/metal.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Классификация сети: metal - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/metal/metal.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: metal - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/metal/metal.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: metal - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/metal/metal.00097.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: blues - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/metal/metal.00098.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Классификация сети: metal - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/metal/metal.00099.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Классификация сети: metal - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/pop/pop.00090.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# Классификация сети: pop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/pop/pop.00091.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Классификация сети: pop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/pop/pop.00092.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Классификация сети: pop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/pop/pop.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Классификация сети: pop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/pop/pop.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: pop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/pop/pop.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Классификация сети: pop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/pop/pop.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Классификация сети: pop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/pop/pop.00097.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Классификация сети: pop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/pop/pop.00098.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: pop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/pop/pop.00099.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: pop - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/reggae/reggae.00090.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: reggae - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/reggae/reggae.00091.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: reggae - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/reggae/reggae.00092.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: reggae - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/reggae/reggae.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Классификация сети: rock - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/reggae/reggae.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Классификация сети: country - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/reggae/reggae.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Классификация сети: hiphop - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/reggae/reggae.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Классификация сети: reggae - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/reggae/reggae.00097.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Классификация сети: country - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/reggae/reggae.00098.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Классификация сети: reggae - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/reggae/reggae.00099.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Классификация сети: rock - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/rock/rock.00090.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Классификация сети: blues - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/rock/rock.00091.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Классификация сети: metal - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/rock/rock.00092.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Классификация сети: rock - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/rock/rock.00093.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# Классификация сети: country - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/rock/rock.00094.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Классификация сети: metal - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/rock/rock.00095.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Классификация сети: country - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/rock/rock.00096.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Классификация сети: country - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/rock/rock.00097.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: rock - ВЕРНО :-)
# ---------------------------------------------------------------
# Файл: ./genres/rock/rock.00098.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Классификация сети: country - НЕВЕРНО.
# ---------------------------------------------------------------
# Файл: ./genres/rock/rock.00099.au
# Векторы для предсказания: (1, 37)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Классификация сети: country - НЕВЕРНО.
# ---------------------------------------------------------------
# === Обработано образцов: 100, из них распознано верно: 56, доля верных: 56.0% ===
